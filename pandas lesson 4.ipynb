# %% [markdown]
# # DataFrame 에 값 쓰기

# %%
import pandas as pd

iphone_df = pd.read_csv(r'c:desktop\data\iphone.csv' ,index_col=0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8', '메모리'] ='2.5GB'
#column 변경

# %%
iphone_df
#변경 사항 적용 확인
# Out:
#                       출시일  디스플레이    메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7    2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5    3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2.5GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5    3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8    3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8    4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5    4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8', '출시 버전'] = 'iOS 10.5'
#column 변경
iphone_df
#변경 사항 적용 확인
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No
# iPhone 8       2017-11-03   5.8  3GB  iOS 10.5     Yes
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8']
# Out:
# 출시일        2017-09-22
# 디스플레이             4.7
# 메모리             2.5GB
# 출시 버전        iOS 10.5
# Face ID            No
# Name: iPhone 8, dtype: object

# %%
#전체 줄 변경
iphone_df.loc['iPhone 8'] = ['2017-11-03', '5.8', '3GB', 'iOS 11.1', 'Yes']
iphone_df
#변경 사항 확인
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No
# iPhone 8       2017-11-03   5.8  3GB  iOS 11.1     Yes
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes

# %%
iphone_df['디스플레이']
# Out:
# iPhone 7         4.7
# iPhone 7 Plus    5.5
# iPhone 8         5.8
# iPhone 8 Plus    5.5
# iPhone X         5.8
# iPhone XS        5.8
# iPhone XS Max    6.5
# Name: 디스플레이, dtype: object

# %%
iphone_df['디스플레이'] = ['1.0in', '2.5in', '3.8in', '3.5in', '4.8in', '5.8in', '7.5in']
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16  1.0in  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16  2.5in  3GB  iOS 10.0      No
# iPhone 8       2017-11-03  3.8in  3GB  iOS 10.5     Yes
# iPhone 8 Plus  2017-09-22  3.5in  3GB  iOS 11.0      No
# iPhone X       2017-11-03  4.8in  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21  5.8in  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21  7.5in  4GB  iOS 12.0     Yes

# %%
iphone_df['Face ID'] = 'Yes'
iphone_df['Face ID']
#모두 동일하게 바꿀 경우 list 사용하지 않고 그냥 'yes', 'no', 'xxxx'써주면 됨.
# Out:
# iPhone 7         Yes
# iPhone 7 Plus    Yes
# iPhone 8         Yes
# iPhone 8 Plus    Yes
# iPhone X         Yes
# iPhone XS        Yes
# iPhone XS Max    Yes
# Name: Face ID, dtype: object

# %%
iphone_df[['디스플레이', 'Face ID']]
# Out:
#                디스플레이 Face ID
# iPhone 7       1.0in     Yes
# iPhone 7 Plus  2.5in     Yes
# iPhone 8       3.8in     Yes
# iPhone 8 Plus  3.5in     Yes
# iPhone X       4.8in     Yes
# iPhone XS      5.8in     Yes
# iPhone XS Max  7.5in     Yes

# %%
iphone_df[['디스플레이', 'Face ID']] = 'x'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16     x  2GB  iOS 10.0       x
# iPhone 7 Plus  2016-09-16     x  3GB  iOS 10.0       x
# iPhone 8       2017-11-03     x  3GB  iOS 10.5       x
# iPhone 8 Plus  2017-09-22     x  3GB  iOS 11.0       x
# iPhone X       2017-11-03     x  3GB  iOS 11.1       x
# iPhone XS      2018-09-21     x  4GB  iOS 12.0       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0       x

# %%
iphone_df.loc[['iPhone 7', 'iPhone X']] = 'o'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7                o     o    o         o       o
# iPhone 7 Plus  2016-09-16     x  3GB  iOS 10.0       x
# iPhone 8       2017-11-03     x  3GB  iOS 10.5       x
# iPhone 8 Plus  2017-09-22     x  3GB  iOS 11.0       x
# iPhone X                o     o    o         o       o
# iPhone XS      2018-09-21     x  4GB  iOS 12.0       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0       x

# %%
iphone_df.loc['iPhone 7' : 'iPhone X'] = 'o'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7                o     o    o         o       o
# iPhone 7 Plus           o     o    o         o       o
# iPhone 8                o     o    o         o       o
# iPhone 8 Plus           o     o    o         o       o
# iPhone X                o     o    o         o       o
# iPhone XS      2018-09-21     x  4GB  iOS 12.0       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0       x

# %%
import pandas as pd

iphone_df = pd.read_csv(r'c:desktop\data\iphone.csv' ,index_col=0)
iphone_df
#처음 상태로 돌리기위해 다시한번입력
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc[iphone_df['디스플레이'] > 5] ='P'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus           P     P    P         P       P
# iPhone 8       2017-09-22   4.7  2GB  iOS 11.0      No
# iPhone 8 Plus           P     P    P         P       P
# iPhone X                P     P    P         P       P
# iPhone XS               P     P    P         P       P
# iPhone XS Max           P     P    P         P       P

# %%
iphone_df.iloc[[1, 3], [1, 4]] = 'x'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus           P     x    P         P       x
# iPhone 8       2017-09-22   4.7  2GB  iOS 11.0      No
# iPhone 8 Plus           P     x    P         P       x
# iPhone X                P     P    P         P       P
# iPhone XS               P     P    P         P       P
# iPhone XS Max           P     P    P         P       P
